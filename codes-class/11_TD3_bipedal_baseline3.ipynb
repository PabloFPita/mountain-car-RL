# %%
import gymnasium as gym
import numpy as np

from stable_baselines3 import TD3
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise

vec_env = gym.make("BipedalWalker-v3", render_mode="rgb_array")

# %%
model = TD3("MlpPolicy", vec_env, verbose=1)
model.learn(total_timesteps=25_000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 443      |
# |    ep_rew_mean     | -87      |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 65       |
# |    time_elapsed    | 27       |
# |    total_timesteps | 1772     |
# | train/             |          |
# |    actor_loss      | -1.14    |
# |    critic_loss     | 8.52     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1649     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 263      |
# |    ep_rew_mean     | -105     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 64       |
# |    time_elapsed    | 32       |
# |    total_timesteps | 2101     |
# | train/             |          |
# |    actor_loss      | 1.13     |
# |    critic_loss     | 38.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1979     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 456      |
# |    ep_rew_mean     | -106     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 82       |
# |    time_elapsed    | 65       |
# |    total_timesteps | 5466     |
# | train/             |          |
# |    actor_loss      | -0.525   |
# |    critic_loss     | 19.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3786     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 454      |
# |    ep_rew_mean     | -110     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 74       |
# |    time_elapsed    | 98       |
# |    total_timesteps | 7266     |
# | train/             |          |
# |    actor_loss      | -1       |
# |    critic_loss     | 12.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5586     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 401      |
# |    ep_rew_mean     | -110     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 59       |
# |    time_elapsed    | 134      |
# |    total_timesteps | 8020     |
# | train/             |          |
# |    actor_loss      | -0.68    |
# |    critic_loss     | 8.17     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7739     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 353      |
# |    ep_rew_mean     | -113     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 58       |
# |    time_elapsed    | 143      |
# |    total_timesteps | 8466     |
# | train/             |          |
# |    actor_loss      | -0.322   |
# |    critic_loss     | 9.39     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8309     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 370      |
# |    ep_rew_mean     | -116     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 58       |
# |    time_elapsed    | 176      |
# |    total_timesteps | 10350    |
# | train/             |          |
# |    actor_loss      | 0.447    |
# |    critic_loss     | 4.47     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10190    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 380      |
# |    ep_rew_mean     | -115     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 58       |
# |    time_elapsed    | 209      |
# |    total_timesteps | 12174    |
# | train/             |          |
# |    actor_loss      | 0.989    |
# |    critic_loss     | 3.59     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11997    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 345      |
# |    ep_rew_mean     | -116     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 57       |
# |    time_elapsed    | 214      |
# |    total_timesteps | 12431    |
# | train/             |          |
# |    actor_loss      | 2.11     |
# |    critic_loss     | 4.77     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12281    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 318      |
# |    ep_rew_mean     | -117     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 58       |
# |    time_elapsed    | 218      |
# |    total_timesteps | 12705    |
# | train/             |          |
# |    actor_loss      | 2.44     |
# |    critic_loss     | 4.05     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12542    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 295      |
# |    ep_rew_mean     | -117     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 57       |
# |    time_elapsed    | 223      |
# |    total_timesteps | 12978    |
# | train/             |          |
# |    actor_loss      | 2.73     |
# |    critic_loss     | 3.47     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12827    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 277      |
# |    ep_rew_mean     | -118     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 57       |
# |    time_elapsed    | 229      |
# |    total_timesteps | 13280    |
# | train/             |          |
# |    actor_loss      | 3.73     |
# |    critic_loss     | 4.15     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13124    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 264      |
# |    ep_rew_mean     | -118     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 57       |
# |    time_elapsed    | 236      |
# |    total_timesteps | 13703    |
# | train/             |          |
# |    actor_loss      | 4.02     |
# |    critic_loss     | 4.49     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13525    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 251      |
# |    ep_rew_mean     | -119     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 57       |
# |    time_elapsed    | 243      |
# |    total_timesteps | 14071    |
# | train/             |          |
# |    actor_loss      | 4.7      |
# |    critic_loss     | 4.99     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13940    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 240      |
# |    ep_rew_mean     | -119     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 57       |
# |    time_elapsed    | 248      |
# |    total_timesteps | 14376    |
# | train/             |          |
# |    actor_loss      | 5.7      |
# |    critic_loss     | 4.66     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14218    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 230      |
# |    ep_rew_mean     | -119     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 57       |
# |    time_elapsed    | 254      |
# |    total_timesteps | 14748    |
# | train/             |          |
# |    actor_loss      | 6.07     |
# |    critic_loss     | 5.23     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14568    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 222      |
# |    ep_rew_mean     | -119     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 57       |
# |    time_elapsed    | 260      |
# |    total_timesteps | 15072    |
# | train/             |          |
# |    actor_loss      | 6.96     |
# |    critic_loss     | 5.01     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14872    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 213      |
# |    ep_rew_mean     | -119     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 57       |
# |    time_elapsed    | 265      |
# |    total_timesteps | 15338    |
# | train/             |          |
# |    actor_loss      | 7.79     |
# |    critic_loss     | 4.42     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15190    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 205      |
# |    ep_rew_mean     | -119     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 57       |
# |    time_elapsed    | 270      |
# |    total_timesteps | 15589    |
# | train/             |          |
# |    actor_loss      | 8.19     |
# |    critic_loss     | 4.8      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15455    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -119     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 57       |
# |    time_elapsed    | 276      |
# |    total_timesteps | 15972    |
# | train/             |          |
# |    actor_loss      | 9.41     |
# |    critic_loss     | 4.57     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15799    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 195      |
# |    ep_rew_mean     | -119     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 57       |
# |    time_elapsed    | 283      |
# |    total_timesteps | 16388    |
# | train/             |          |
# |    actor_loss      | 10.3     |
# |    critic_loss     | 4.97     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 16190    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 206      |
# |    ep_rew_mean     | -118     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 62       |
# |    time_elapsed    | 289      |
# |    total_timesteps | 18169    |
# | train/             |          |
# |    actor_loss      | 9.86     |
# |    critic_loss     | 4.58     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 16489    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 203      |
# |    ep_rew_mean     | -118     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 57       |
# |    time_elapsed    | 323      |
# |    total_timesteps | 18701    |
# | train/             |          |
# |    actor_loss      | 12       |
# |    critic_loss     | 5.73     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 18503    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -118     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 57       |
# |    time_elapsed    | 331      |
# |    total_timesteps | 19168    |
# | train/             |          |
# |    actor_loss      | 13       |
# |    critic_loss     | 5.9      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 18922    |
# ---------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-e65a68ded2b8> in <module>
#       1 model = TD3("MlpPolicy", vec_env, verbose=1)
# ----> 2 model.learn(total_timesteps=25_000)
#
# E:\ANACONDA\envs\tf\lib\site-packages\stable_baselines3\td3\td3.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     220         progress_bar: bool = False,
#     221     ) -> SelfTD3:
# --> 222         return super().learn(
#     223             total_timesteps=total_timesteps,
#     224             callback=callback,
#
# E:\ANACONDA\envs\tf\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     345                 # Special case when the user passes `gradient_steps=0`
#     346                 if gradient_steps > 0:
# --> 347                     self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     348
#     349         callback.on_training_end()
#
# E:\ANACONDA\envs\tf\lib\site-packages\stable_baselines3\td3\td3.py in train(self, gradient_steps, batch_size)
#     187             self.critic.optimizer.zero_grad()
#     188             critic_loss.backward()
# --> 189             self.critic.optimizer.step()
#     190
#     191             # Delayed policy updates
#
# E:\ANACONDA\envs\tf\lib\site-packages\torch\optim\optimizer.py in wrapper(*args, **kwargs)
#     383                             )
#     384
# --> 385                 out = func(*args, **kwargs)
#     386                 self._optimizer_step_code()
#     387
#
# E:\ANACONDA\envs\tf\lib\site-packages\torch\optim\optimizer.py in _use_grad(self, *args, **kwargs)
#      74             torch.set_grad_enabled(self.defaults['differentiable'])
#      75             torch._dynamo.graph_break()
# ---> 76             ret = func(self, *args, **kwargs)
#      77         finally:
#      78             torch._dynamo.graph_break()
#
# E:\ANACONDA\envs\tf\lib\site-packages\torch\optim\adam.py in step(self, closure)
#     164                 state_steps)
#     165
# --> 166             adam(
#     167                 params_with_grad,
#     168                 grads,
#
# E:\ANACONDA\envs\tf\lib\site-packages\torch\optim\adam.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     314         func = _single_tensor_adam
#     315
# --> 316     func(params,
#     317          grads,
#     318          exp_avgs,
#
# E:\ANACONDA\envs\tf\lib\site-packages\torch\optim\adam.py in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     390         # Decay the first and second moment running average coefficient
#     391         exp_avg.lerp_(grad, 1 - beta1)
# --> 392         exp_avg_sq.mul_(beta2).addcmul_(grad, grad.conj(), value=1 - beta2)
#     393
#     394         if capturable or differentiable:
#
# KeyboardInterrupt:

# %%
# Testing the results with 10 episodes

vec_env = model.get_env()

episodes =10

for ep in range(episodes):
    #vec_env = model.get_env()
    obs = vec_env.reset()
    done = False
    while not done:
        action, _states = model.predict(obs)
        obs, rewards, done, info = vec_env.step(action)
        vec_env.render()
        print(rewards)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-ad0263fdea6f> in <module>
#      12         action, _states = model.predict(obs)
#      13         obs, rewards, done, info = vec_env.step(action)
# ---> 14         vec_env.render()
#      15         print(rewards)
#
# E:\ANACONDA\envs\tf\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py in render(self, mode)
#     101         :param mode: The rendering type.
#     102         """
# --> 103         return super().render(mode=mode)
#     104
#     105     def _save_obs(self, env_idx: int, obs: VecEnvObs) -> None:
#
# E:\ANACONDA\envs\tf\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py in render(self, mode)
#     253         if mode == "rgb_array" or mode == "human":
#     254             # call the render method of the environments
# --> 255             images = self.get_images()
#     256             # Create a big image by tiling images from subprocesses
#     257             bigimg = tile_images(images)  # type: ignore[arg-type]
#
# E:\ANACONDA\envs\tf\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py in get_images(self)
#      92             )
#      93             return [None for _ in self.envs]
# ---> 94         return [env.render() for env in self.envs]  # type: ignore[misc]
#      95
#      96     def render(self, mode: Optional[str] = None) -> Optional[np.ndarray]:
#
# E:\ANACONDA\envs\tf\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py in <listcomp>(.0)
#      92             )
#      93             return [None for _ in self.envs]
# ---> 94         return [env.render() for env in self.envs]  # type: ignore[misc]
#      95
#      96     def render(self, mode: Optional[str] = None) -> Optional[np.ndarray]:
#
# E:\ANACONDA\envs\tf\lib\site-packages\gymnasium\core.py in render(self)
#     469     def render(self) -> RenderFrame | list[RenderFrame] | None:
#     470         """Uses the :meth:`render` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 471         return self.env.render()
#     472
#     473     def close(self):
#
# E:\ANACONDA\envs\tf\lib\site-packages\gymnasium\core.py in render(self)
#     469     def render(self) -> RenderFrame | list[RenderFrame] | None:
#     470         """Uses the :meth:`render` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 471         return self.env.render()
#     472
#     473     def close(self):
#
# E:\ANACONDA\envs\tf\lib\site-packages\gymnasium\wrappers\order_enforcing.py in render(self, *args, **kwargs)
#      68                 "set `disable_render_order_enforcing=True` on the OrderEnforcer wrapper."
#      69             )
# ---> 70         return self.env.render(*args, **kwargs)
#      71
#      72     @property
#
# E:\ANACONDA\envs\tf\lib\site-packages\gymnasium\wrappers\env_checker.py in render(self, *args, **kwargs)
#      65             return env_render_passive_checker(self.env, *args, **kwargs)
#      66         else:
# ---> 67             return self.env.render(*args, **kwargs)
#      68
#      69     @property
#
# E:\ANACONDA\envs\tf\lib\site-packages\gymnasium\envs\box2d\bipedal_walker.py in render(self)
#     638         )
#     639
# --> 640         pygame.transform.scale(self.surf, (SCALE, SCALE))
#     641
#     642         pygame.draw.polygon(
#
# TypeError: integer argument expected, got float

# %%
vec_env.close()

# %%
vec_env = gym.make("BipedalWalker-v3", 'rgb_array')
